# %%
# Imports and setup
import time
import random
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Base URL for the first page
TABELOG_BASE_URL = "https://tabelog.com/en/tokyo/rstLst/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}


def safe_extract(element, css_selector, attribute=None, default=None):
    """
    Safely extracts text or an attribute from a BeautifulSoup element.

    Args:
        element: The parent BeautifulSoup element.
        css_selector: The CSS selector string to find the target element.
        attribute: The attribute to extract (e.g., "href"). If None, extracts text.
        default: The default value to return if extraction fails.

    Returns:
        The extracted text/attribute value or the default value.
    """
    try:
        target = element.select_one(css_selector)
        if attribute:
            return target[attribute] if target else default
        return target.text.strip() if target else default
    except Exception:
        return default

def clean_price(price_text):
    """
    Cleans the price text to remove 'JPY' and formats it as a numeric range.

    Args:
        price_text: A string containing the price, e.g., "JPY 50,000 - JPY 59,999".

    Returns:
        A string with the cleaned price range, e.g., "50000 - 59999", or None if invalid.
    """
    if not price_text:
        return None
    # Remove 'JPY' and commas, then strip whitespace
    cleaned_text = re.sub(r"JPY|\s|,", "", price_text)
    return cleaned_text

# Function to scrape a single page
def scrape_tabelog_page(url, starting_rank):
    """
    Scrapes a page of restaurants and fetches additional details from their individual pages.

    Args:
        url: The URL of the page to scrape.
        starting_rank: The ranking value to start from.

    Returns:
        A tuple containing:
            - List of restaurant data on the page.
            - The next starting rank value.
    """
    try:
        # Retry mechanism for the main page request
        for _ in range(3):  # Retry up to 3 times
            response = requests.get(url, headers=HEADERS)
            if response.status_code == 200:
                break
            time.sleep(2)  # Wait 2 seconds before retrying
        else:
            print(f"Failed to fetch the main page: {url}")
            return [], starting_rank  # Return empty data and current rank

        soup = BeautifulSoup(response.text, "html.parser")
        restaurant_cards = soup.find_all("div", class_="list-rst js-bookmark js-rst-cassette-wrap")
        data = []

        # Initialize ranking counter from the passed-in starting rank
        ranking = starting_rank

        for card in restaurant_cards:
            try:
                # Extract basic details from the card
                name = safe_extract(card, "a.list-rst__rst-name-target.cpy-rst-name")
                restaurant_url = safe_extract(card, "a.list-rst__rst-name-target.cpy-rst-name", "href")
                rating = safe_extract(card, "span.c-rating__val.c-rating__val--strong.list-rst__rating-val")

                # Extract price range from the aria-label "Average dinner price"
                price_range = None
                try:
                    price_element = card.select_one('li.c-rating-v3 i[aria-label="Average dinner price"] + span.c-rating-v3__val')
                    if price_element:
                        raw_price = price_element.text.strip()  # Extract text
                        price_range = clean_price(raw_price)   # Pass the cleaned text to clean_price
                except Exception as e:
                    print(f"Error extracting price range: {e}")

                # Extract the number of reviews
                review_count = None
                review_element = card.select_one("em.list-rst__rvw-count-num.cpy-review-count")
                if review_element:
                    review_count = review_element.text.strip()

                # Extract detailed information (e.g., address, categories) if needed
                nearest_station = None
                categories = None
                address = None
                reservation_only = False

                # Add a random sleep to avoid overloading the server
                time.sleep(random.uniform(2, 5))  # Sleep for 2-5 seconds

                try:
                    for _ in range(3):  # Retry up to 3 times for individual pages
                        page_response = requests.get(restaurant_url, headers=HEADERS)
                        if page_response.status_code == 200:
                            break
                        time.sleep(2)  # Wait before retrying
                    else:
                        print(f"Failed to fetch details for {name}: {restaurant_url}")
                        continue

                    rest_soup = BeautifulSoup(page_response.text, "html.parser")
                    details = rest_soup.find_all("dl", class_="rdheader-subinfo__item")

                    # Extract Nearest Station and Categories
                    for detail in details:
                        dt = detail.find("dt", class_="rdheader-subinfo__item-title")
                        dd = detail.find("dd", class_="rdheader-subinfo__item-text")
                        if not dt or not dd:
                            continue

                        title = dt.text.strip()
                        if title == "Nearest station：":
                            nearest_station_span = dd.select_one("span.linktree__parent-target-text")
                            if nearest_station_span:
                                nearest_station = nearest_station_span.text.strip()
                        elif title == "Categories：":
                            categories_span = dd.select_one("span.linktree__parent-target-text")
                            if categories_span:
                                categories = categories_span.text.strip()

                    # Extract Address and Reservation Status
                    table = rest_soup.find("table", class_="c-table c-table--form rstinfo-table__table")
                    if table:
                        rows = table.find_all("tr")
                        for row in rows:
                            th = row.find("th")
                            td = row.find("td")

                            if not th or not td:
                                continue

                            title = th.text.strip()
                            if title == "Address":
                                address_p = td.find("p", class_="rstinfo-table__address")
                                if address_p:
                                    address = address_p.text.strip()
                            elif title == "Reservation availability":
                                reservation_status = td.find("p", class_="rstinfo-table__reserve-status")
                                if reservation_status:
                                    text = reservation_status.text.strip()
                                    if "Reservation only" in text or "Reservations available" in text:
                                        reservation_only = "Reservation only" in text

                except Exception as e:
                    print(f"Error fetching detailed info for {restaurant_url}: {e}")

                # Append the data for this restaurant
                data.append({
                    "Ranking": ranking,
                    "Name": name,
                    "URL": restaurant_url,
                    "Rating": rating,
                    "Price Range": price_range,
                    "Review Count": review_count,
                    "Nearest Station": nearest_station,
                    "Categories": categories,
                    "Address": address,
                    "Reservation Only": reservation_only
                })

                ranking += 1  # Increment ranking for the next restaurant

            except Exception as e:
                print(f"Error processing restaurant card: {e}")

        return data, ranking  # Return updated rank value

    except Exception as e:
        print(f"Error scraping the main page: {e}")
        return [], starting_rank  # Return empty data and current rank on error


def scrape_tabelog_pages(num_pages):
    """
    Scrapes multiple pages of restaurants from Tabelog.

    Args:
        num_pages: The number of pages to scrape.

    Returns:
        A list of all restaurant data.
    """
    all_data = []
    current_rank = 1  # Initialize the global ranking counter

    for page in range(1, num_pages + 1):
        print(f"Scraping page {page}...")
        url = f"{TABELOG_BASE_URL}{page}/?SrtT=rt" if page > 1 else TABELOG_BASE_URL + "?SrtT=rt"

        # Add a random delay before the request
        time.sleep(random.uniform(5, 15))  # Wait between 5 and 15 seconds
        
        page_data, current_rank = scrape_tabelog_page(url, current_rank)  # Pass in and update the rank

        if page_data:  # Only extend if data is not empty
            all_data.extend(page_data)
        else:
            print(f"Stopping at page {page} due to an error.")
            break

        # Be polite by adding a delay between requests
        time.sleep(2)

    return all_data

# %%
# Scrape the first 2 pages (adjust as needed)
data = scrape_tabelog_pages(num_pages=10)

# Create a DataFrame and export to CSV
df = pd.DataFrame(data)
#df.to_csv("tabelog_top_restaurants_tokyo.csv", index=False)

#print("Data scraped and saved to 'tabelog_top_restaurants_tokyo.csv'")
df
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
#      Ranking                           Name  \
# 0          1              Shimbashi Hoshino
# 1          2  Nihonbashi Kakigaracho Sugita
# 2          3                            aca
# 3          4           Higashiazabu Amamoto
# 4          5                      Matsukawa
# ..       ...                            ...
# 195      196                 Ginza Kitafuku
# 196      197                  Onarimon Haru
# 197      198                      Mori Fuji
# 198      199                          tens.
# 199      200                Raa Menya Shima
#
#                                                    URL Rating  Price Range  \
# 0    https://tabelog.com/en/tokyo/A1314/A131401/131...   4.65  50000-59999
# 1    https://tabelog.com/en/tokyo/A1302/A130204/130...   4.64  40000-49999
# 2    https://tabelog.com/en/tokyo/A1302/A130202/132...   4.63  60000-79999
# 3    https://tabelog.com/en/tokyo/A1314/A131401/131...   4.62  60000-79999
# 4    https://tabelog.com/en/tokyo/A1307/A130701/131...   4.61  80000-99999
# ..                                                 ...    ...          ...
# 195  https://tabelog.com/en/tokyo/A1301/A130101/131...   4.01  40000-49999
# 196  https://tabelog.com/en/tokyo/A1314/A131401/132...   4.01  40000-49999
# 197  https://tabelog.com/en/tokyo/A1309/A130905/132...   4.01  30000-39999
# 198  https://tabelog.com/en/tokyo/A1306/A130603/133...   4.01  20000-29999
# 199  https://tabelog.com/en/tokyo/A1304/A130401/132...   4.00            -
#
#     Review Count              Nearest Station        Categories  \
# 0            275                Onarimon Sta.  Japanese Cuisine
# 1            897             Suitengumae Sta.             Sushi
# 2            523           Mitsukoshimae Sta.             Spain
# 3            572            Akabanebashi Sta.             Sushi
# 4            509        Roppongi Itchome Sta.  Japanese Cuisine
# ..           ...                          ...               ...
# 195          265                   Ginza Sta.              Crab
# 196          206                Onarimon Sta.  Japanese Cuisine
# 197          121     Ushigome Kagurazaka Sta.  Japanese Cuisine
# 198           78                Gaiemmae Sta.           Italian
# 199         1769  Nishi Shinjuku Gochome Sta.             Ramen
#
#                               Address  Reservation Only
# 0                       東京都港区新橋5-31-3              True
# 1    東京都中央区日本橋蛎殻町1-33-6 ビューハイツ日本橋 B1F              True
# 2              東京都中央区日本橋室町2-1-1 三井2号館              True
# 3            東京都港区東麻布1-7-9 ザ・ソノビル 102              True
# 4           東京都港区赤坂1-11-6 赤坂テラスハウス １階              True
# ..                                ...               ...
# 195          東京都中央区銀座7-4-5 銀座745ビル 3F              True
# 196             東京都港区芝大門1-2-2 中川ビル 1F              True
# 197        東京都新宿区納戸町32-3 ザ・フィガロ市ヶ谷 1F              True
# 198         東京都港区南青山2-27-28 グラン青山 B1F             False
# 199                   東京都渋谷区本町3-41-12              True
#
# [200 rows x 10 columns]

# %%
# Export the DataFrame to a CSV file
output_file = "tabelog_data.csv"
df.to_csv(output_file, index=False, encoding="utf-8-sig")  # Use utf-8-sig for Japanese characters
print(f"Data successfully exported to {output_file}")
# Out:
# Data successfully exported to tabelog_data.csv

# %%
# Great! We have our table. Now we need to get latitude and longitude for each 
# restaurant. We'll use a geocoding API for that.

import pandas as pd
import requests
import time

# Function to geocode an address
def geocode_address(address, api_key):
    """
    Geocodes an address using the Google Maps Geocoding API.
    
    Args:
        address (str): The address or place name to geocode.
        api_key (str): Your Google Maps API key.
    
    Returns:
        tuple: A tuple containing (latitude, longitude), or (None, None) if not found.
    """
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "address": address,
        "key": api_key
    }
    try:
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            status = data.get("status")
            if status == "OK":
                location = data["results"][0]["geometry"]["location"]
                return location["lat"], location["lng"]
            else:
                error_message = data.get("error_message", "No additional error message provided.")
                print(f"Geocoding failed for '{address}': {status} - {error_message}")
        else:
            print(f"HTTP error {response.status_code} for '{address}'")
    except Exception as e:
        print(f"Unexpected error during geocoding for '{address}': {e}")
    return None, None

# Load data from a file named 'tabelog_data' (no .csv extension)
input_file = "tabelog_data.csv"
try:
    # Load the file, assuming the first row contains column headers
    tabelog_data = pd.read_csv(input_file, encoding="utf-8-sig", header=0)
    print(f"Data loaded successfully from {input_file}")
except FileNotFoundError:
    print(f"Error: The file '{input_file}' was not found.")
    exit()

# Verify the columns
if "Address" not in tabelog_data.columns:
    print("Error: The input file does not contain an 'Address' column.")
    exit()

# API Key
API_KEY = ""

# Geocode each address and add latitude/longitude to the DataFrame
latitudes = []
longitudes = []

for i, row in tabelog_data.iterrows():
    address = row["Address"]
    lat, lon = geocode_address(address, API_KEY)
    latitudes.append(lat)
    longitudes.append(lon)
    print(f"Processed {i + 1}/{len(tabelog_data)}: {address} -> Lat: {lat}, Lon: {lon}")
    time.sleep(0.2)  # Add a delay to avoid hitting rate limits

# Add the latitudes and longitudes as new columns
tabelog_data["Latitude"] = latitudes
tabelog_data["Longitude"] = longitudes

# Export the updated DataFrame to a new file
output_file = "tabelog_data_geocoded.csv"
tabelog_data.to_csv(output_file, index=False, encoding="utf-8-sig")
print(f"Geocoded data successfully exported to {output_file}")
# Out:
# Data loaded successfully from tabelog_data.csv
# Processed 1/200: 東京都港区新橋5-31-3 -> Lat: 35.6624582, Lon: 139.7553081
# Processed 2/200: 東京都中央区日本橋蛎殻町1-33-6 ビューハイツ日本橋 B1F -> Lat: 35.6818515, Lon: 139.7849984
# Processed 3/200: 東京都中央区日本橋室町2-1-1 三井2号館 -> Lat: 35.6868636, Lon: 139.7724807
# Processed 4/200: 東京都港区東麻布1-7-9 ザ・ソノビル 102 -> Lat: 35.6573486, Lon: 139.7434681
# Processed 5/200: 東京都港区赤坂1-11-6 赤坂テラスハウス １階 -> Lat: 35.6674621, Lon: 139.7423903
# Processed 6/200: 東京都港区六本木1-4-5 アークヒルズサウスタワー 1Ｆ -> Lat: 35.6656056, Lon: 139.7394165
# Processed 7/200: 東京都中央区銀座8-10-2 ルアンビル B1F 2F -> Lat: 35.6680421, Lon: 139.7627122
# Processed 8/200: 東京都渋谷区恵比寿2-3-4 -> Lat: 35.648029, Lon: 139.7184741
# Processed 9/200: 東京都中央区銀座2-8-17 ハビウル銀座2 B1 -> Lat: 35.673039, Lon: 139.7678421
# Processed 10/200: 東京都港区西麻布3-21-3 オリンピアード麻布霞坂 2F -> Lat: 35.6598526, Lon: 139.7251681
# Processed 11/200: 東京都港区南麻布4-7-5 -> Lat: 35.6495836, Lon: 139.7283406
# Processed 12/200: 東京都中央区銀座5-9-19 ＭＣビル3Ｆ -> Lat: 35.6704606, Lon: 139.7652779
# Processed 13/200: 東京都新宿区四谷1-22-1 -> Lat: 35.6875649, Lon: 139.7278518
# Processed 14/200: 東京都港区麻布十番2-8-6 ラベイユ麻布十番 2F -> Lat: 35.6555619, Lon: 139.7346056
# Processed 15/200: 東京都品川区北品川6-7-29 ガーデンシティ品川 御殿山 1F -> Lat: 35.6239862, Lon: 139.7333701
# Processed 16/200: 東京都千代田区有楽町1-1-2 東京ミッドタウン日比谷 3F -> Lat: 35.6737436, Lon: 139.7591762
# Processed 17/200: 東京都新宿区東五軒町5-5 2F -> Lat: 35.7063525, Lon: 139.7397557
# Processed 18/200: 東京都港区赤坂3-9-12 メトロビル 4F -> Lat: 35.6768672, Lon: 139.7362432
# Processed 19/200: 東京都港区白金1-29-13 白金ヴィレッジ 1F -> Lat: 35.643222, Lon: 139.7336488
# Processed 20/200: 東京都目黒区青葉台1-28-2 EXA 1F -> Lat: 35.6474043, Lon: 139.6951547
# Processed 21/200: 東京都港区 -> Lat: 35.65808130000001, Lon: 139.7515077
# Processed 22/200: 東京都港区麻布台1-11-10 日総ビル1F -> Lat: 35.6610343, Lon: 139.7437607
# Processed 23/200: 東京都品川区上大崎2-14-12 -> Lat: 35.6342653, Lon: 139.7169019
# Processed 24/200: 東京都港区西麻布3丁目17-23 プティコワン西麻布2F -> Lat: 35.6580758, Lon: 139.7239833
# Processed 25/200: 東京都港区西麻布2-26-4 -> Lat: 35.6602169, Lon: 139.7194309
# Processed 26/200: 東京都渋谷区 -> Lat: 35.6619707, Lon: 139.703795
# Processed 27/200: 東京都中央区銀座7-5-5 -> Lat: 35.6698913, Lon: 139.7617874
# Processed 28/200: 東京都中央区銀座6-4-3 GICROS GINZA GEMS 9F -> Lat: 35.6715901, Lon: 139.7619561
# Processed 29/200: 東京都港区西麻布1-15-3 西麻布UOUビル 1F -> Lat: 35.6617996, Lon: 139.7232725
# Processed 30/200: 東京都新宿区四谷1-11 陽臨堂ビル　１Ｆ -> Lat: 35.6856077, Lon: 139.7282908
# Processed 31/200: 東京都渋谷区恵比寿西2-13-16 ラングス代官山 1F -> Lat: 35.6508458, Lon: 139.7060166
# Processed 32/200: 東京都港区三田2-17-29 グランデ三田 B1F -> Lat: 35.6474922, Lon: 139.739948
# Processed 33/200: 東京都新宿区東五軒町5-5 -> Lat: 35.7063525, Lon: 139.7397557
# Processed 34/200: 東京都品川区南大井3-11-5 MAKIMURA BLD 1F -> Lat: 35.5908393, Lon: 139.7354263
# Processed 35/200: 東京都中央区銀座2-10-11 マロニエ通り銀座館 2F -> Lat: 35.6720816, Lon: 139.7682929
# Processed 36/200: 東京都千代田区丸の内1-11-1 パシフィックセンチュリープレイス -> Lat: 35.6779865, Lon: 139.7669297
# Processed 37/200: 東京都港区南麻布4-5-66 -> Lat: 35.6511293, Lon: 139.7237414
# Processed 38/200: 東京都渋谷区西原3-23-1 -> Lat: 35.6706199, Lon: 139.6834603
# Processed 39/200: 東京都目黒区三田1-13-1 恵比寿ガーデンプレイス -> Lat: 35.6419011, Lon: 139.7145339
# Processed 40/200: 東京都豊島区池袋2-53-2 池袋ESビル 1F -> Lat: 35.7337706, Lon: 139.7090115
# Processed 41/200: 東京都新宿区神楽坂5-37 高村ビル　１Ｆ -> Lat: 35.70124089999999, Lon: 139.7394364
# Processed 42/200: 東京都中央区新富1-8-2 grandir ginza east 1F -> Lat: 35.6729143, Lon: 139.7744821
# Processed 43/200: 東京都渋谷区恵比寿2-37-8 グランデュオ広尾 1F -> Lat: 35.6452662, Lon: 139.7222179
# Processed 44/200: 東京都中央区京橋2-4-16 明治京橋ビル1F -> Lat: 35.6770691, Lon: 139.7692033
# Processed 45/200: 東京都港区赤坂3-9-2 No.R赤坂見附 1F -> Lat: 35.6772902, Lon: 139.7362154
# Processed 46/200: 東京都港区赤坂6-3-13 -> Lat: 35.6708882, Lon: 139.7352853
# Processed 47/200: 東京都港区西新橋1-18-8 報徳ビル 1F -> Lat: 35.6675596, Lon: 139.753299
# Processed 48/200: 東京都新宿区神楽坂5-37 相良ビル 1F -> Lat: 35.7013408, Lon: 139.7391271
# Processed 49/200: 東京都千代田区紀尾井町1-3 東京ガーデンテラス紀尾井町 達磨テラス 3F -> Lat: 35.6793415, Lon: 139.7371812
# Processed 50/200: 東京都港区南青山2-6-15 -> Lat: 35.6715648, Lon: 139.7218885
# Processed 51/200: 東京都港区白金台5-13-14 白金台THE1000 Ｂ1F -> Lat: 35.6377436, Lon: 139.7227802
# Processed 52/200: 東京都中央区銀座1-21-14 -> Lat: 35.6725118, Lon: 139.7707091
# Processed 53/200: 東京都中央区 -> Lat: 35.6706392, Lon: 139.7719892
# Processed 54/200: 東京都中央区銀座5-4-6 ロイヤルクリスタル銀座 9Ｆ -> Lat: 35.6717161, Lon: 139.7633311
# Processed 55/200: 東京都中央区日本橋人形町2-22-11 井上ビル 1F -> Lat: 35.6862565, Lon: 139.784509
# Processed 56/200: 東京都港区西麻布3-2-34 西麻布ヒルズ B1F -> Lat: 35.6594393, Lon: 139.7267062
# Processed 57/200: 東京都港区六本木4-4-2 ヒルサイドパレス六本木 B1F -> Lat: 35.6652188, Lon: 139.7324833
# Processed 58/200: 東京都新宿区荒木町7-13 森戸ビル 1Ｆ -> Lat: 35.6891044, Lon: 139.7222649
# Processed 59/200: 東京都中央区銀座2-10-11 マロニエ通り銀座館 3F -> Lat: 35.6720816, Lon: 139.7682929
# Processed 60/200: 東京都港区南青山2-11-11 ARISTO南青山 1F -> Lat: 35.6712475, Lon: 139.7209746
# Processed 61/200: 東京都渋谷区恵比寿1-11-5 GEMS恵比寿 8F -> Lat: 35.6463405, Lon: 139.7117909
# Processed 62/200: 東京都千代田区有楽町1-9-4 蚕糸会館　Ｂ１Ｆ -> Lat: 35.6751122, Lon: 139.7609752
# Processed 63/200: 東京都新宿区四谷1-9-4 -> Lat: 35.6860739, Lon: 139.7279873
# Processed 64/200: 東京都中央区八重洲2-2-1 東京ミッドタウン八重洲 3F -> Lat: 35.6794084, Lon: 139.7689311
# Processed 65/200: 東京都文京区本郷3-27-9 アンリツビル B1F～1F -> Lat: 35.706599, Lon: 139.7624227
# Processed 66/200: 東京都渋谷区鶯谷町7-12 TAKビル 1F -> Lat: 35.6540804, Lon: 139.7022691
# Processed 67/200: 東京都中央区銀座8-3-1 銀座時傳ビル 6F -> Lat: 35.6692505, Lon: 139.7592458
# Processed 68/200: 東京都港区六本木7-3-21 来山ビル 2F -> Lat: 35.66537, Lon: 139.727931
# Processed 69/200: 東京都渋谷区神宮前2-3-18 建築家会館JIA館 -> Lat: 35.6731932, Lon: 139.7127606
# Processed 70/200: 東京都新宿区神楽坂5-7 -> Lat: 35.7022532, Lon: 139.738698
# Processed 71/200: 東京都中央区日本橋兜町1-4 M-SQUAREビル 1F -> Lat: 35.6827422, Lon: 139.7793861
# Processed 72/200: 東京都港区白金3-14-1 第１マンション　１Ｆ -> Lat: 35.6453454, Lon: 139.7283008
# Processed 73/200: 東京都渋谷区東3-16-1 ベルザ恵比寿 1F -> Lat: 35.6497997, Lon: 139.7100875
# Processed 74/200: 東京都渋谷区代々木4-22-17 クイーンズ代々木 1F -> Lat: 35.6812558, Lon: 139.6913014
# Processed 75/200: 東京都江東区常盤2-14-11 -> Lat: 35.6842687, Lon: 139.7983122
# Processed 76/200: 東京都千代田区内幸町1-1-1 帝国ホテル東京 本館 中2F -> Lat: 35.672454, Lon: 139.7579015
# Processed 77/200: 東京都港区元麻布3-6-34 カーム元麻布 1F -> Lat: 35.6570579, Lon: 139.7287062
# Processed 78/200: 東京都中央区築地3-7-2 第五銀座ウェスト築地ビル 1F -> Lat: 35.6679031, Lon: 139.7737344
# Processed 79/200: 東京都中央区日本橋2-10-11 ordin日本橋ビル 6F -> Lat: 35.6809812, Lon: 139.7746068
# Processed 80/200: 東京都港区南青山5-4-30 ヴィラソレイユE号 -> Lat: 35.6624602, Lon: 139.7143561
# Processed 81/200: 東京都港区新橋2-15-10 -> Lat: 35.6663414, Lon: 139.7566148
# Processed 82/200: 東京都杉並区阿佐谷南3-44-4 B1F -> Lat: 35.7045006, Lon: 139.6339252
# Processed 83/200: 東京都港区六本木3-8-8 ＷＯＯビル　１Ｆ -> Lat: 35.663284, Lon: 139.7345874
# Processed 84/200: 東京都港区南青山4-16-15 FPG links MINAMIAOYAMA B2F -> Lat: 35.6660014, Lon: 139.7167799
# Processed 85/200: 東京都港区麻布台1-3-1 麻布台ヒルズ タワープラザ 3F -> Lat: 35.6609166, Lon: 139.7405604
# Processed 86/200: 東京都渋谷区渋谷2-2-2 青山ルカビル B1F -> Lat: 35.6607645, Lon: 139.7085533
# Processed 87/200: 東京都足立区鹿浜3-13-4 -> Lat: 35.7799029, Lon: 139.7523707
# Processed 88/200: 東京都港区東麻布3-7-5 -> Lat: 35.6562703, Lon: 139.7385296
# Processed 89/200: 東京都杉並区成田東4-33-9 -> Lat: 35.6978032, Lon: 139.6387833
# Processed 90/200: 東京都港区赤坂4-2-2 赤坂DNプラザビル 2F -> Lat: 35.6761426, Lon: 139.7356764
# Processed 91/200: 東京都港区白金台4-2-7 bld桜なみき 2F -> Lat: 35.6393592, Lon: 139.7281112
# Processed 92/200: 東京都新宿区荒木町15 サンシャトー四谷203 -> Lat: 35.6910245, Lon: 139.7246904
# Processed 93/200: 東京都葛飾区東四ツ木4-14-4 -> Lat: 35.7387478, Lon: 139.8333638
# Processed 94/200: 東京都港区六本木4-2-35 VORT六本木Dual's B1F (旧 URABAN STYLE ROPPONGI MIKAWADAI) -> Lat: 35.6647207, Lon: 139.7335553
# Processed 95/200: 東京都墨田区墨田3-25-7 -> Lat: 35.730703, Lon: 139.8194926
# Processed 96/200: 東京都千代田区一番町3-8 大宮ビル 1F -> Lat: 35.6877165, Lon: 139.7433184
# Processed 97/200: 東京都中央区銀座7-5-15 AG1ビル 3F -> Lat: 35.6697935, Lon: 139.7610478
# Processed 98/200: 東京都大田区西蒲田5-20-2 -> Lat: 35.5655425, Lon: 139.7145757
# Processed 99/200: 東京都中央区銀座6-8-7 交詢ビル　4Ｆ -> Lat: 35.6702693, Lon: 139.7626704
# Processed 100/200: 東京都渋谷区千駄ヶ谷3-7-13 原宿東急アパートメントＢ１ -> Lat: 35.6769032, Lon: 139.7043254
# Processed 101/200: 東京都港区西麻布2-24-14 バルビゾン73 B1F -> Lat: 35.6601523, Lon: 139.7224744
# Processed 102/200: 東京都港区南青山2-27-16 篠塚ビル B1F -> Lat: 35.66858819999999, Lon: 139.7169946
# Processed 103/200: 東京都北区中里1-29-1 -> Lat: 35.7379077, Lon: 139.7527579
# Processed 104/200: 東京都港区南青山6-4-6 青山ＡＬＬＥＹ 1F -> Lat: 35.6615191, Lon: 139.7164092
# Processed 105/200: 東京都港区麻布十番1-6-1 THE V-CITY 麻布十番 PLACE 6F -> Lat: 35.6566963, Lon: 139.7343454
# Processed 106/200: 東京都港区南青山6-6-22 ルナロッサ　Ｂ１Ｆ -> Lat: 35.6602545, Lon: 139.7177949
# Processed 107/200: 東京都江東区福住1-3-1 -> Lat: 35.6755048, Lon: 139.7930987
# Processed 108/200: 東京都港区六本木3-8-7 PALビル 1F -> Lat: 35.6631657, Lon: 139.7345428
# Processed 109/200: 東京都新宿区四谷4-8 ライオンズ四谷タワーゲート店舗棟 B1F -> Lat: 35.6880701, Lon: 139.7166065
# Processed 110/200: 東京都新宿区四谷三栄町15-2 ＪＨＣビル 1F -> Lat: 35.6885631, Lon: 139.7270337
# Processed 111/200: 東京都中央区銀座5-11-12 日総第26ビル 3F -> Lat: 35.6694982, Lon: 139.7654875
# Processed 112/200: 東京都中央区 -> Lat: 35.6706392, Lon: 139.7719892
# Processed 113/200: 東京都中央区銀座8-6-20 銀座八番館 B1F -> Lat: 35.6686564, Lon: 139.7605628
# Processed 114/200: 東京都台東区駒形2-1-17 -> Lat: 35.7067673, Lon: 139.7953869
# Processed 115/200: 東京都世田谷区玉川3-21-8 -> Lat: 35.6161111, Lon: 139.6243322
# Processed 116/200: 東京都港区芝公園1-7-10 -> Lat: 35.6574137, Lon: 139.7526412
# Processed 117/200: 東京都渋谷区神宮前2-19-12 -> Lat: 35.673458, Lon: 139.7101767
# Processed 118/200: 東京都中央区湊3-4-2 Vann Amor 1F -> Lat: 35.6698099, Lon: 139.77769
# Processed 119/200: 東京都中央区銀座7-3-13 ニューギンザビル B1F -> Lat: 35.670056, Lon: 139.7602259
# Processed 120/200: 東京都港区南麻布4-5-66 2F -> Lat: 35.6511293, Lon: 139.7237414
# Processed 121/200: 東京都中央区晴海3-1 晴海乗船場 -> Lat: 35.6561242, Lon: 139.7772135
# Processed 122/200: 東京都中央区銀座4-5-5 ミキモトビル Ｂ１Ｆ -> Lat: 35.6718956, Lon: 139.7653829
# Processed 123/200: 東京都港区西麻布1-9-5 2F -> Lat: 35.6611846, Lon: 139.7253052
# Processed 124/200: 東京都台東区雷門2-14-6 -> Lat: 35.7104438, Lon: 139.7950559
# Processed 125/200: 東京都渋谷区広尾5-13-6 ARISTO広尾ビル 1F -> Lat: 35.6498903, Lon: 139.7212573
# Processed 126/200: 東京都千代田区有楽町1-1-2 ミッドタウン日比谷 7F -> Lat: 35.6739622, Lon: 139.7596299
# Processed 127/200: 東京都港区元麻布3-2-3 けやき坂 NEST 1F -> Lat: 35.657563, Lon: 139.7276683
# Processed 128/200: 東京都新宿区神楽坂3-5-5 -> Lat: 35.7008106, Lon: 139.7408453
# Processed 129/200: 東京都港区南青山2-2-15 ウィン青山 1F -> Lat: 35.6715979, Lon: 139.7238344
# Processed 130/200: 東京都港区元赤坂1-5-20 ロイヤル赤坂サルーン1F -> Lat: 35.6775332, Lon: 139.7324515
# Processed 131/200: 東京都中央区銀座7-8-13 Brown Place 9F -> Lat: 35.6689218, Lon: 139.7619535
# Processed 132/200: 東京都中央区日本橋人形町1-5-10 日本橋芸者新道ビル 3F -> Lat: 35.6852265, Lon: 139.7820724
# Processed 133/200: 東京都中央区銀座5-9-16 GINZA-A-5 2F -> Lat: 35.6701935, Lon: 139.7650003
# Processed 134/200: 東京都港区新橋4-9-1 新橋プラザビル B1F -> Lat: 35.6642596, Lon: 139.756543
# Processed 135/200: 東京都中央区銀座5-5-18 銀座藤小西 9F -> Lat: 35.6716281, Lon: 139.7637047
# Processed 136/200: 東京都台東区浅草4-10-5 -> Lat: 35.7184014, Lon: 139.7970136
# Processed 137/200: 東京都港区六本木3-1-1 六本木ティーキューブ1F -> Lat: 35.6655427, Lon: 139.7382225
# Processed 138/200: 東京都港区赤坂3-13-6 国際天野ビル 7F -> Lat: 35.6730582, Lon: 139.7377192
# Processed 139/200: 東京都渋谷区恵比寿2-10-5 ROZIS 1F -> Lat: 35.6456743, Lon: 139.7168163
# Processed 140/200: 東京都港区赤坂3-11-7 ソシアル赤坂ビル 4F -> Lat: 35.6745648, Lon: 139.7375604
# Processed 141/200: 東京都中央区銀座6-3-18 La.La.Grande GINZA 2F -> Lat: 35.6717919, Lon: 139.7612388
# Processed 142/200: 東京都港区西新橋2-13-6 ミタニビル 1F -> Lat: 35.6667277, Lon: 139.7515822
# Processed 143/200: 東京都港区南青山7-13-13 フォレストビル B1F -> Lat: 35.6571045, Lon: 139.718034
# Processed 144/200: 東京都港区虎ノ門5-8-1 麻布台ヒルズ ガーデンプラザA 2F -> Lat: 35.6624927, Lon: 139.743728
# Processed 145/200: 東京都渋谷区宇田川町11-1 松沼ビル　１Ｆ -> Lat: 35.6626422, Lon: 139.6972857
# Processed 146/200: 東京都中央区新富2-5-5 新富MSビル 1F -> Lat: 35.6715885, Lon: 139.7740274
# Processed 147/200: 東京都港区西麻布2-16-4 第二吉山ビル 1F -> Lat: 35.6617031, Lon: 139.7207984
# Processed 148/200: 東京都杉並区阿佐谷南3-44-2 新井ビル　1F -> Lat: 35.70462, Lon: 139.6343204
# Processed 149/200: 東京都新宿区大久保1-12-3 カーサ第二新宿 1F -> Lat: 35.6985348, Lon: 139.7034628
# Processed 150/200: 東京都港区西麻布2-24-7 西麻布MAビル 1F -> Lat: 35.6610177, Lon: 139.721816
# Processed 151/200: 東京都新宿区神楽坂6-43 K's Place102 -> Lat: 35.7036291, Lon: 139.7353152
# Processed 152/200: 東京都港区南麻布2-10-13 OJハウス 101 -> Lat: 35.6479882, Lon: 139.7359092
# Processed 153/200: 東京都港区虎ノ門1-23-3 虎ノ門ヒルズガーデンハウス 1F -> Lat: 35.666653, Lon: 139.748574
# Processed 154/200: 東京都中央区銀座5-5-12 HULIC&New GINZA MIYUKI 5 10F -> Lat: 35.6710873, Lon: 139.7631833
# Processed 155/200: 東京都中央区銀座8-10-17 銀座サザンビル 8F -> Lat: 35.6681009, Lon: 139.7625482
# Processed 156/200: 東京都港区東麻布1-29-15 東麻布296ビル 1F -> Lat: 35.6552757, Lon: 139.7424808
# Processed 157/200: 東京都江東区東陽1-11-3 桜マンション 1F -> Lat: 35.6684257, Lon: 139.8102337
# Processed 158/200: 東京都港区東麻布2-14-8 フィル•パーク東麻布 1F -> Lat: 35.6570615, Lon: 139.7405577
# Processed 159/200: 東京都世田谷区砧8-13-8 ジベ成城　１Ｆ -> Lat: 35.6416003, Lon: 139.6057903
# Processed 160/200: 東京都渋谷区渋谷2-3-1 青山ポニーハイム　２Ｆ -> Lat: 35.6599442, Lon: 139.7088359
# Processed 161/200: 東京都港区南青山7-10-10 パークアクシス南青山7丁目 1F -> Lat: 35.6588855, Lon: 139.7188033
# Processed 162/200: 東京都千代田区紀尾井町1-3 東京ガーデンテラス紀尾井町 3F -> Lat: 35.6799926, Lon: 139.7379363
# Processed 163/200: 東京都港区六本木4-12-5 六本木144ビル 3F -> Lat: 35.6644785, Lon: 139.7316233
# Processed 164/200: 東京都杉並区阿佐ヶ谷南2-17-2 -> Lat: 35.705267, Lon: 139.6359043
# Processed 165/200: 東京都千代田区六番町4-3 GEMS市ヶ谷 9F -> Lat: 35.6891599, Lon: 139.7352518
# Processed 166/200: 東京都港区北青山3-13-1 北青山関根ビル B1F -> Lat: 35.6640889, Lon: 139.7094477
# Processed 167/200: 東京都中央区入船3-8-9 ドミシールカワイ 1F -> Lat: 35.6705639, Lon: 139.7771191
# Processed 168/200: 東京都港区赤坂6-3-16 赤坂ストリートビルディング 2F -> Lat: 35.6710888, Lon: 139.7354193
# Processed 169/200: 東京都港区南青山4-11-2 南青山Kビル 1F -> Lat: 35.6660359, Lon: 139.7181042
# Processed 170/200: 東京都杉並区荻窪5-20-7 吉田ビル　１Ｆ -> Lat: 35.7025554, Lon: 139.6196993
# Processed 171/200: 東京都新宿区下落合3-22-13 -> Lat: 35.7224723, Lon: 139.7006505
# Processed 172/200: 東京都墨田区押上1-38-4 清流ビル１Ｆ -> Lat: 35.7098647, Lon: 139.8158909
# Processed 173/200: 東京都中央区京橋2-5-2 A・M京橋ビル 1F -> Lat: 35.6764566, Lon: 139.7704595
# Processed 174/200: 東京都港区新橋6-13-3 1F -> Lat: 35.6619119, Lon: 139.7540636
# Processed 175/200: 東京都港区白金5-7-8 ウイング綱島 1F -> Lat: 35.6444824, Lon: 139.7276922
# Processed 176/200: 東京都港区赤坂3-9-2 No.R赤坂見附 1F -> Lat: 35.6772902, Lon: 139.7362154
# Processed 177/200: 東京都世田谷区北沢5-3-12 B1F -> Lat: 35.6689079, Lon: 139.671468
# Processed 178/200: 東京都目黒区中目黒1-5-12 ATRIO 1F -> Lat: 35.6441889, Lon: 139.7023379
# Processed 179/200: 東京都港区虎ノ門1-11-14 第二ジェスペールビル　１Ｆ -> Lat: 35.66895530000001, Lon: 139.7501934
# Processed 180/200: 東京都港区南青山3-14-27 IJK南青山れい 1F -> Lat: 35.6655992, Lon: 139.7146293
# Processed 181/200: 東京都渋谷区代々木2-6-5 -> Lat: 35.68795360000001, Lon: 139.698908
# Processed 182/200: 東京都渋谷区神宮前5-23-3 -> Lat: 35.6644778, Lon: 139.7046895
# Processed 183/200: 東京都青梅市梅郷4-695-1 -> Lat: 35.788712, Lon: 139.2217761
# Processed 184/200: 東京都中央区銀座5-5-13 坂口ビル　9Ｆ -> Lat: 35.6712111, Lon: 139.7634809
# Processed 185/200: 東京都中央区銀座7-7-7 GINZA777 ADC BUILDING 6F -> Lat: 35.6692404, Lon: 139.7619253
# Processed 186/200: 東京都目黒区下目黒3-16-2 1F -> Lat: 35.6270637, Lon: 139.7086689
# Processed 187/200: 東京都港区赤坂6-13-8 -> Lat: 35.6699391, Lon: 139.7340557
# Processed 188/200: 東京都港区南麻布1-27-7 クリフサイドビル 1F -> Lat: 35.6499925, Lon: 139.7331743
# Processed 189/200: 東京都渋谷区恵比寿西2-17-5 サンビレッジ代官山 2F -> Lat: 35.6489302, Lon: 139.7059561
# Processed 190/200: 東京都新宿区納戸町22 -> Lat: 35.6981502, Lon: 139.7325667
# Processed 191/200: 東京都新宿区荒木町16-16 ベルウッドビル B1F -> Lat: 35.6916821, Lon: 139.7242203
# Processed 192/200: 東京都武蔵野市吉祥寺東町3-8-8 カサ吉祥寺２ -> Lat: 35.708977, Lon: 139.5907094
# Processed 193/200: 東京都中央区銀座8-10-3 三鈴ビル　Ｂ１Ｆ -> Lat: 35.6679846, Lon: 139.7626384
# Processed 194/200: 東京都中央区銀座5-9-5 -> Lat: 35.6703772, Lon: 139.7655179
# Processed 195/200: 東京都中央区銀座6-3-15 -> Lat: 35.6714621, Lon: 139.7608853
# Processed 196/200: 東京都中央区銀座7-4-5 銀座745ビル 3F -> Lat: 35.6701249, Lon: 139.7611427
# Processed 197/200: 東京都港区芝大門1-2-2 中川ビル 1F -> Lat: 35.6601761, Lon: 139.7545584
# Processed 198/200: 東京都新宿区納戸町32-3 ザ・フィガロ市ヶ谷 1F -> Lat: 35.6977182, Lon: 139.7338071
# Processed 199/200: 東京都港区南青山2-27-28 グラン青山 B1F -> Lat: 35.6697281, Lon: 139.7168511
# Processed 200/200: 東京都渋谷区本町3-41-12 -> Lat: 35.6883038, Lon: 139.6809081
# Geocoded data successfully exported to tabelog_data_geocoded.csv
